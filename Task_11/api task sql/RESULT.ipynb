# %% [markdown]
# ## Result

# %% [markdown]
# # 1 Inserting into table

# %% [markdown]
# ![record%20insert.png](attachment:record%20insert.png)

# %% [markdown]
# ### Inserted records

# %% [markdown]
# ![show%20inserted%20record.png](attachment:show%20inserted%20record.png)

# %% [markdown]
# # 2. Deleting Record Via API

# %% [markdown]
# ![delete.png](attachment:delete.png)

# %% [markdown]
# ![del%20result.png](attachment:del%20result.png)

# %% [markdown]
# # 3. Update record via API

# %% [markdown]
# ![update.png](attachment:update.png)

# %% [markdown]
# # 4. Fetching records via API

# %% [markdown]
# ## fetch all records

# %% [markdown]
# ![show%20inserted%20record.png](attachment:show%20inserted%20record.png)

# %% [markdown]
# ## fetch particular record by id

# %% [markdown]
# ![fetch_api.png](attachment:fetch_api.png)
